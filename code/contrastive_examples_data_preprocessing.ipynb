# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %%
from datasets import concatenate_datasets, load_dataset
from datasets import Dataset, DatasetDict

# %% [markdown]
# # Read Dataset

# %%
df = pd.read_json("../data/yelp/yelp.jsonl", lines=True)

# %%
df
# Out:
#                           ty_id review_date  score                  author  \
# 0        NW366Ota9w52nYofW99u1g                 -1  FwqVjnpwpcW6fHQxAYigYg
# 1        NW366Ota9w52nYofW99u1g                 -1  ZNQXrXdCfRX5m08ddcYgtQ
# 2        NW366Ota9w52nYofW99u1g                 -1  gm6W0Ys2_b5d9bUcfL8aYw
# 3        NW366Ota9w52nYofW99u1g                 -1  iwIJDqCQfxpfnKTYu6vbNQ
# 4        NW366Ota9w52nYofW99u1g                 -1  yq1ZN_38X3hOWrUJ_ZTKCw
# ...                         ...         ...    ...                     ...
# 1038121  6bgjcFOy4WHMyw62_1V9Pw                 -1  gTJVaTPMyVzjzDhaX447hA
# 1038122  6bgjcFOy4WHMyw62_1V9Pw                 -1  SzLKZVb24ZlenSBFTBGGTQ
# 1038123  6bgjcFOy4WHMyw62_1V9Pw                 -1  2Lh31bK4AFis5WKXcutDdQ
# 1038124  6bgjcFOy4WHMyw62_1V9Pw                 -1  EkC8wieEPelR_EzSmQchdQ
# 1038125  6bgjcFOy4WHMyw62_1V9Pw                 -1  WLlOW0GgPUSKHlgcDZXxFw
#
#         language title                                            content  \
# 0             en        Good cheap place to get away from the heat a t...
# 1             en        If you are looking for something to do, take a...
# 2             en        Wow, this is a clean and neat establishment! W...
# 3             en        This place was hard to find and pretty much a ...
# 4             en        Yep, read the other reviews and decided to try...
# ...          ...   ...                                                ...
# 1038121       en        We ordered two sandwiches, two sodas, and a bo...
# 1038122       en        Mehh... came in at 9pm, one hour before close....
# 1038123       en        I love coming to Panera! Ashley Love and Luke ...
# 1038124       en        So I walk into The Panera Rest. On Ft Apache t...
# 1038125       en        Love Panera bread! So lucky to have them cater...
#
#                                                extractions  \
# 0        [{'opinion': 'Good cheap', 'aspect': 'place', ...
# 1        [{'opinion': 'really old', 'aspect': 'theater'...
# 2        [{'opinion': 'clean', 'aspect': 'establishment...
# 3        [{'opinion': 'hard to find', 'aspect': 'place'...
# 4        [{'opinion': 'OK', 'aspect': 'ticket prices', ...
# ...                                                    ...
# 1038121  [{'opinion': 'mediocre', 'aspect': 'Sandwich',...
# 1038122  [{'opinion': 'Saddest', 'aspect': 'grilled che...
# 1038123  [{'opinion': 'amazing and friendly', 'aspect':...
# 1038124                                                 []
# 1038125  [{'opinion': 'Love', 'aspect': 'Panera', 'sid'...
#
#                                                  sentences
# 0        [[Good, cheap, place, to, get, away, from, the...
# 1        [[If, you, are, looking, for, something, to, d...
# 2        [[Wow, ,, this, is, a, clean, and, neat, estab...
# 3        [[This, place, was, hard, to, find, and, prett...
# 4        [[Yep, ,, read, the, other, reviews, and, deci...
# ...                                                    ...
# 1038121  [[We, ordered, two, sandwiches, ,, two, sodas,...
# 1038122  [[Mehh, ..., came, in, at, 9, pm, ,, one, hour...
# 1038123  [[I, love, coming, to, Panera, !], [Ashley, Lo...
# 1038124  [[So, I, walk, into, The, Panera, Rest, .], [O...
# 1038125  [[Love, Panera, bread, !], [So, lucky, to, hav...
#
# [1038126 rows x 9 columns]

# %% [markdown]
# ## Opinion Extraction Preview

# %%
df['extraction_len'] = df['extractions'].apply(lambda x: len(x))
df['sentence_len'] = df['sentences'].apply(lambda x: len(x))

# %%
test_idx = 2
print(df['content'].iloc[test_idx])
print(len(df['sentences'].iloc[test_idx]))
df['extractions'].iloc[test_idx]
# Out:
# Wow, this is a clean and neat establishment! We came in for a 3:30 show on Friday and shared the ~600-person theater with 20-something people. The lobby and hall were pretty dark, and the entrance itself was sketchily situated on a backlot-like side road/street/alley, but the bathroom, theater and seating looked and smelled very clean and sterile, and the staff was very courteous. The sound might've been a bit low, but otherwise it was a clean, straightforward and intimate experience, and if you find yourself on the Vegas Strip and looking for a mainstream/Hollywood/blockbuster movie, this is a great find.
# 4
# [{'opinion': 'clean',
#   'aspect': 'establishment',
#   'sid': 0,
#   'asp_start': 8,
#   'asp_end': 8,
#   'op_start': 5,
#   'op_end': 5,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'positive'},
#  {'opinion': '~600-person',
#   'aspect': 'theater',
#   'sid': 1,
#   'asp_start': 15,
#   'asp_end': 15,
#   'op_start': 14,
#   'op_end': 14,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'neutral'},
#  {'opinion': 'pretty dark',
#   'aspect': 'hall',
#   'sid': 2,
#   'asp_start': 3,
#   'asp_end': 3,
#   'op_start': 5,
#   'op_end': 6,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'negative'},
#  {'opinion': 'very courteous',
#   'aspect': 'staff',
#   'sid': 2,
#   'asp_start': 44,
#   'asp_end': 44,
#   'op_start': 46,
#   'op_end': 47,
#   'attribute': 'staff',
#   'sentiment': 'positive'},
#  {'opinion': 'sketchily situated',
#   'aspect': 'entrance',
#   'sid': 2,
#   'asp_start': 10,
#   'asp_end': 10,
#   'op_start': 13,
#   'op_end': 14,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'negative'},
#  {'opinion': 'sterile',
#   'aspect': 'seating',
#   'sid': 2,
#   'asp_start': 33,
#   'asp_end': 33,
#   'op_start': 40,
#   'op_end': 40,
#   'attribute': 'restaurant -> comfort',
#   'sentiment': 'negative'},
#  {'opinion': 'great',
#   'aspect': 'find',
#   'sid': 3,
#   'asp_start': 45,
#   'asp_end': 45,
#   'op_start': 44,
#   'op_end': 44,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'positive'},
#  {'opinion': 'straightforward',
#   'aspect': 'experience',
#   'sid': 3,
#   'asp_start': 19,
#   'asp_end': 19,
#   'op_start': 16,
#   'op_end': 16,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'positive'},
#  {'opinion': 'low',
#   'aspect': 'sound',
#   'sid': 3,
#   'asp_start': 1,
#   'asp_end': 1,
#   'op_start': 7,
#   'op_end': 7,
#   'attribute': 'restaurant -> atmosphere',
#   'sentiment': 'negative'}]

# %% [markdown]
# # Data Sampling

# %% [markdown]
# ## Sample Top Business Categories

# %%
df_yelp_business = pd.read_json("../data/yelp/business.json", lines=True)

# %%
df_yelp_business = df_yelp_business.rename(columns={'business_id': 'ty_id'})
df = df.merge(df_yelp_business[['ty_id', 'name', 'categories']], on=['ty_id'])
df['categories'].value_counts().index.tolist()
df['categories_list'] = df['categories'].apply(lambda x: x.split(", ") if pd.notnull(x) else [])
df = df.reset_index()

# %% [markdown]
# **Get Top Businesses Categories**

# %%
top_domains = df['categories_list'].explode().value_counts()
temp_df = df.explode(['categories_list'])
temp_df = temp_df.set_index('categories_list').loc[top_domains.index.tolist(),].reset_index()
temp_df = temp_df.drop_duplicates(subset=['index'])

# %%
temp_df['categories_list'].value_counts()
# Out:
# Restaurants                     704679
# Beauty & Spas                    73428
# Food                             69920
# Automotive                       38373
# Shopping                         34190
# Nightlife                        20970
# Home Services                    19407
# Event Planning & Services        18336
# Active Life                      12933
# Arts & Entertainment             12094
# Health & Medical                 10527
# Pets                              9665
# Local Services                    6598
# Hotels & Travel                   4739
# Professional Services              706
# Public Services & Government       450
# Education                          404
# Financial Services                 347
# Religious Organizations            137
# Local Flavor                       128
# Mass Media                          95
# Name: categories_list, dtype: int64

# %% [markdown]
# **Select top business categories**

# %%
selected_top_domains = ['Restaurants', 'Hotels', 'Beauty & Spas', 'Arts & Entertainment', 'Automotive']
selected_df = df[df['categories_list'].apply(lambda x: any([cat in selected_top_domains for cat in x]))]
selected_df['domain'] = selected_df['categories_list'].apply(lambda x: list(set(x) & set(selected_top_domains)))
selected_df = selected_df[selected_df['domain'].str.len() == 1]
selected_df['domain'] = selected_df['domain'].apply(lambda x: x[0])
# Out:
# /tmp/ipykernel_3816/3855826295.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['domain'] = selected_df['categories_list'].apply(lambda x: list(set(x) & set(selected_top_domains)))
# /tmp/ipykernel_3816/3855826295.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['domain'] = selected_df['domain'].apply(lambda x: x[0])

# %%
selected_df['domain'].value_counts()
# Out:
# Restaurants             686343
# Beauty & Spas            72324
# Automotive               41784
# Arts & Entertainment     25249
# Hotels                    8658
# Name: domain, dtype: int64

# %% [markdown]
# ## Sample Top Businesses Per Category

# %%
k = 50
# k = 30

# %%
top_k_business = []
for domain in selected_df['domain'].unique():
    top_k_business += selected_df.loc[selected_df['domain'] == domain, 'ty_id'].value_counts().head(k).index.tolist()

# %%
selected_df = selected_df[df['ty_id'].isin(top_k_business)]
# Out:
# /tmp/ipykernel_3816/3778154810.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   selected_df = selected_df[df['ty_id'].isin(top_k_business)]

# %%
selected_df
# Out:
#            index                   ty_id review_date  score  \
# 306994    306994  iCCsd62g79PDjswXaqxltw                 -1
# 306995    306995  iCCsd62g79PDjswXaqxltw                 -1
# 306996    306996  iCCsd62g79PDjswXaqxltw                 -1
# 306997    306997  iCCsd62g79PDjswXaqxltw                 -1
# 306998    306998  iCCsd62g79PDjswXaqxltw                 -1
# ...          ...                     ...         ...    ...
# 1038121  1038121  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038122  1038122  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038123  1038123  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038124  1038124  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038125  1038125  6bgjcFOy4WHMyw62_1V9Pw                 -1
#
#                          author language title  \
# 306994   S4nbxIsCCYj0VIhRF8BuDg       en
# 306995   HNmHme33Ar8EnskRVmBypg       en
# 306996   AFBb3pYlCVTpBy2ZvvqsiA       en
# 306997   4tUGHviSJ7RPpxHhbXiuQw       en
# 306998   GLZP_OfjcQLWivre2uF-Zw       en
# ...                         ...      ...   ...
# 1038121  gTJVaTPMyVzjzDhaX447hA       en
# 1038122  SzLKZVb24ZlenSBFTBGGTQ       en
# 1038123  2Lh31bK4AFis5WKXcutDdQ       en
# 1038124  EkC8wieEPelR_EzSmQchdQ       en
# 1038125  WLlOW0GgPUSKHlgcDZXxFw       en
#
#                                                    content  \
# 306994   Hey Mrs. Robinson! \n\nThe Graduate was a fant...
# 306995   The rooms are decent sized, and the view is aw...
# 306996   My son is a future sun devil and I found this ...
# 306997   Awesome place to stay when near ASU. Friendly ...
# 306998   Bad hotel. Very run down. Light broken in our ...
# ...                                                    ...
# 1038121  We ordered two sandwiches, two sodas, and a bo...
# 1038122  Mehh... came in at 9pm, one hour before close....
# 1038123  I love coming to Panera! Ashley Love and Luke ...
# 1038124  So I walk into The Panera Rest. On Ft Apache t...
# 1038125  Love Panera bread! So lucky to have them cater...
#
#                                                extractions  \
# 306994   [{'opinion': 'modern', 'aspect': 'twist', 'sid...
# 306995   [{'opinion': 'decent sized', 'aspect': 'rooms'...
# 306996   [{'opinion': 'awesome', 'aspect': 'employees',...
# 306997   [{'opinion': 'Awesome', 'aspect': 'place', 'si...
# 306998   [{'opinion': 'Bad', 'aspect': 'hotel', 'sid': ...
# ...                                                    ...
# 1038121  [{'opinion': 'mediocre', 'aspect': 'Sandwich',...
# 1038122  [{'opinion': 'Saddest', 'aspect': 'grilled che...
# 1038123  [{'opinion': 'amazing and friendly', 'aspect':...
# 1038124                                                 []
# 1038125  [{'opinion': 'Love', 'aspect': 'Panera', 'sid'...
#
#                                                  sentences  extraction_len  \
# 306994   [[Hey, Mrs., Robinson, !,   ], [The, Graduate,...               4
# 306995   [[The, rooms, are, decent, sized, ,, and, the,...               7
# 306996   [[My, son, is, a, future, sun, devil, and, I, ...               2
# 306997   [[Awesome, place, to, stay, when, near, ASU, ....               7
# 306998   [[Bad, hotel, .], [Very, run, down, .], [Light...               2
# ...                                                    ...             ...
# 1038121  [[We, ordered, two, sandwiches, ,, two, sodas,...               5
# 1038122  [[Mehh, ..., came, in, at, 9, pm, ,, one, hour...               2
# 1038123  [[I, love, coming, to, Panera, !], [Ashley, Lo...               3
# 1038124  [[So, I, walk, into, The, Panera, Rest, .], [O...               0
# 1038125  [[Love, Panera, bread, !], [So, lucky, to, hav...               2
#
#          sentence_len            name  \
# 306994              6  Graduate Tempe
# 306995              6  Graduate Tempe
# 306996              3  Graduate Tempe
# 306997              5  Graduate Tempe
# 306998             11  Graduate Tempe
# ...               ...             ...
# 1038121             8    Panera Bread
# 1038122            11    Panera Bread
# 1038123             5    Panera Bread
# 1038124             7    Panera Bread
# 1038125             4    Panera Bread
#
#                                                 categories  \
# 306994   Venues & Event Spaces, Event Planning & Servic...
# 306995   Venues & Event Spaces, Event Planning & Servic...
# 306996   Venues & Event Spaces, Event Planning & Servic...
# 306997   Venues & Event Spaces, Event Planning & Servic...
# 306998   Venues & Event Spaces, Event Planning & Servic...
# ...                                                    ...
# 1038121  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038122  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038123  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038124  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038125  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#
#                                            categories_list       domain
# 306994   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306995   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306996   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306997   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306998   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# ...                                                    ...          ...
# 1038121  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038122  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038123  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038124  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038125  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
#
# [35034 rows x 16 columns]

# %% [markdown]
# # Extract Comments

# %%
selected_df
# Out:
#            index                   ty_id review_date  score  \
# 306994    306994  iCCsd62g79PDjswXaqxltw                 -1
# 306995    306995  iCCsd62g79PDjswXaqxltw                 -1
# 306996    306996  iCCsd62g79PDjswXaqxltw                 -1
# 306997    306997  iCCsd62g79PDjswXaqxltw                 -1
# 306998    306998  iCCsd62g79PDjswXaqxltw                 -1
# ...          ...                     ...         ...    ...
# 1038121  1038121  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038122  1038122  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038123  1038123  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038124  1038124  6bgjcFOy4WHMyw62_1V9Pw                 -1
# 1038125  1038125  6bgjcFOy4WHMyw62_1V9Pw                 -1
#
#                          author language title  \
# 306994   S4nbxIsCCYj0VIhRF8BuDg       en
# 306995   HNmHme33Ar8EnskRVmBypg       en
# 306996   AFBb3pYlCVTpBy2ZvvqsiA       en
# 306997   4tUGHviSJ7RPpxHhbXiuQw       en
# 306998   GLZP_OfjcQLWivre2uF-Zw       en
# ...                         ...      ...   ...
# 1038121  gTJVaTPMyVzjzDhaX447hA       en
# 1038122  SzLKZVb24ZlenSBFTBGGTQ       en
# 1038123  2Lh31bK4AFis5WKXcutDdQ       en
# 1038124  EkC8wieEPelR_EzSmQchdQ       en
# 1038125  WLlOW0GgPUSKHlgcDZXxFw       en
#
#                                                    content  \
# 306994   Hey Mrs. Robinson! \n\nThe Graduate was a fant...
# 306995   The rooms are decent sized, and the view is aw...
# 306996   My son is a future sun devil and I found this ...
# 306997   Awesome place to stay when near ASU. Friendly ...
# 306998   Bad hotel. Very run down. Light broken in our ...
# ...                                                    ...
# 1038121  We ordered two sandwiches, two sodas, and a bo...
# 1038122  Mehh... came in at 9pm, one hour before close....
# 1038123  I love coming to Panera! Ashley Love and Luke ...
# 1038124  So I walk into The Panera Rest. On Ft Apache t...
# 1038125  Love Panera bread! So lucky to have them cater...
#
#                                                extractions  \
# 306994   [{'opinion': 'modern', 'aspect': 'twist', 'sid...
# 306995   [{'opinion': 'decent sized', 'aspect': 'rooms'...
# 306996   [{'opinion': 'awesome', 'aspect': 'employees',...
# 306997   [{'opinion': 'Awesome', 'aspect': 'place', 'si...
# 306998   [{'opinion': 'Bad', 'aspect': 'hotel', 'sid': ...
# ...                                                    ...
# 1038121  [{'opinion': 'mediocre', 'aspect': 'Sandwich',...
# 1038122  [{'opinion': 'Saddest', 'aspect': 'grilled che...
# 1038123  [{'opinion': 'amazing and friendly', 'aspect':...
# 1038124                                                 []
# 1038125  [{'opinion': 'Love', 'aspect': 'Panera', 'sid'...
#
#                                                  sentences  extraction_len  \
# 306994   [[Hey, Mrs., Robinson, !,   ], [The, Graduate,...               4
# 306995   [[The, rooms, are, decent, sized, ,, and, the,...               7
# 306996   [[My, son, is, a, future, sun, devil, and, I, ...               2
# 306997   [[Awesome, place, to, stay, when, near, ASU, ....               7
# 306998   [[Bad, hotel, .], [Very, run, down, .], [Light...               2
# ...                                                    ...             ...
# 1038121  [[We, ordered, two, sandwiches, ,, two, sodas,...               5
# 1038122  [[Mehh, ..., came, in, at, 9, pm, ,, one, hour...               2
# 1038123  [[I, love, coming, to, Panera, !], [Ashley, Lo...               3
# 1038124  [[So, I, walk, into, The, Panera, Rest, .], [O...               0
# 1038125  [[Love, Panera, bread, !], [So, lucky, to, hav...               2
#
#          sentence_len            name  \
# 306994              6  Graduate Tempe
# 306995              6  Graduate Tempe
# 306996              3  Graduate Tempe
# 306997              5  Graduate Tempe
# 306998             11  Graduate Tempe
# ...               ...             ...
# 1038121             8    Panera Bread
# 1038122            11    Panera Bread
# 1038123             5    Panera Bread
# 1038124             7    Panera Bread
# 1038125             4    Panera Bread
#
#                                                 categories  \
# 306994   Venues & Event Spaces, Event Planning & Servic...
# 306995   Venues & Event Spaces, Event Planning & Servic...
# 306996   Venues & Event Spaces, Event Planning & Servic...
# 306997   Venues & Event Spaces, Event Planning & Servic...
# 306998   Venues & Event Spaces, Event Planning & Servic...
# ...                                                    ...
# 1038121  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038122  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038123  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038124  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038125  Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#
#                                            categories_list       domain
# 306994   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306995   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306996   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306997   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# 306998   [Venues & Event Spaces, Event Planning & Servi...       Hotels
# ...                                                    ...          ...
# 1038121  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038122  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038123  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038124  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
# 1038125  [Breakfast & Brunch, Soup, Food, Bagels, Salad...  Restaurants
#
# [35034 rows x 16 columns]

# %% [markdown]
# **Extract comments from reviews**

# %%
def extract_opinionated_comments_from_review(grp):
    extractions = grp['extractions'].iloc[0]
    sentences = grp['sentences'].iloc[0]
    
    opinionated_sid_map = {}
    for opinion in (extractions):
        if opinion['sid'] in opinionated_sid_map:
            opinionated_sid_map[opinion['sid']] += [opinion]
        else:
            opinionated_sid_map[opinion['sid']] = [opinion]
    
    opinionated_sentences = [" ".join(sentences[i]) for i in opinionated_sid_map.keys()]
    opinions = []
    aspects = []
    attributes = []
    sentiments = []
    opinion_aspect_pairs = []
    for sent_opinions in opinionated_sid_map.values():
        opinions += [[opinion['opinion'] for opinion in sent_opinions]]
        aspects += [[opinion['aspect'] for opinion in sent_opinions]]
        attributes += [[opinion['attribute'] for opinion in sent_opinions]]
        sentiments += [[opinion['sentiment'] for opinion in sent_opinions]]
        opinion_aspect_pairs += [[opinion['opinion'] + " " + opinion['aspect'] for opinion in sent_opinions]]
    
    opinion_sent_df = pd.DataFrame({'sentences': opinionated_sentences})
    opinion_sent_df['opinions'] = opinions
    opinion_sent_df['aspects'] = aspects
    opinion_sent_df['opinion_aspect_pairs'] = opinion_aspect_pairs
    opinion_sent_df['sid'] = opinionated_sid_map.keys()
    opinion_sent_df['attributes'] = attributes
    opinion_sent_df['sentiments'] = sentiments
    opinion_sent_df['review_content'] = grp['content'].iloc[0]
    opinion_sent_df.insert(0, 'business_id', grp['ty_id'].iloc[0])
    opinion_sent_df.insert(0, 'name', grp['name'].iloc[0])
    opinion_sent_df.insert(0, 'categories', grp['categories'].iloc[0])
    opinion_sent_df.insert(0, 'categories_list', [grp['categories_list'].iloc[0] for i in range(len(opinion_sent_df))])
    opinion_sent_df.insert(0, 'domain', grp['domain'].iloc[0])
    
    return opinion_sent_df

# %%
yelp_sent_df = selected_df.reset_index().groupby(['index']).apply(extract_opinionated_comments_from_review)

# %%
yelp_sent_df
# Out:
#                 domain                                    categories_list  \
# index
# 306994  0       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         1       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# 306995  0       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         1       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         2       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# ...                ...                                                ...
# 1038122 1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038123 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038125 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#
#                                                   categories            name  \
# index
# 306994  0  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         1  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# 306995  0  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         1  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         2  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# ...                                                      ...             ...
# 1038122 1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038123 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#         1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038125 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#         1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#
#                       business_id  \
# index
# 306994  0  iCCsd62g79PDjswXaqxltw
#         1  iCCsd62g79PDjswXaqxltw
# 306995  0  iCCsd62g79PDjswXaqxltw
#         1  iCCsd62g79PDjswXaqxltw
#         2  iCCsd62g79PDjswXaqxltw
# ...                           ...
# 1038122 1  6bgjcFOy4WHMyw62_1V9Pw
# 1038123 0  6bgjcFOy4WHMyw62_1V9Pw
#         1  6bgjcFOy4WHMyw62_1V9Pw
# 1038125 0  6bgjcFOy4WHMyw62_1V9Pw
#         1  6bgjcFOy4WHMyw62_1V9Pw
#
#                                                    sentences  \
# index
# 306994  0  Gorgeous 70 's vintage feel with that modern t...
#         1  I especially liked the convenience of the Norm...
# 306995  0  The rooms are decent sized , and the view is a...
#         1  Employees for the most part after nice althoug...
#         2  The ' theme ' of the hotel I found to be kind ...
# ...                                                      ...
# 1038122 1                             Tomato soup was ok .
# 1038123 0        The staff here is so amazing and friendly !
#         1                 Great food and wonderful service !
# 1038125 0                                Love Panera bread !
#         1                   Everything is always delicious .
#
#                                      opinions               aspects  \
# index
# 306994  0  [modern, boutique style, Gorgeous]  [twist, hotel, feel]
#         1                             [liked]         [convenience]
# 306995  0             [decent sized, awesome]         [rooms, view]
#         1                 [metrosexual, nice]      [men, Employees]
#         2                            [cheesy]               [hotel]
# ...                                       ...                   ...
# 1038122 1                                [ok]         [Tomato soup]
# 1038123 0              [amazing and friendly]               [staff]
#         1                  [Great, wonderful]       [food, service]
# 1038125 0                              [Love]              [Panera]
#         1                  [always delicious]          [Everything]
#
#                                         opinion_aspect_pairs  sid  \
# index
# 306994  0  [modern twist, boutique style hotel, Gorgeous ...  2.0
#         1                                [liked convenience]  3.0
# 306995  0                 [decent sized rooms, awesome view]  0.0
#         1                  [metrosexual men, nice Employees]  1.0
#         2                                     [cheesy hotel]  3.0
# ...                                                      ...  ...
# 1038122 1                                   [ok Tomato soup]  6.0
# 1038123 0                       [amazing and friendly staff]  2.0
#         1                    [Great food, wonderful service]  4.0
# 1038125 0                                      [Love Panera]  0.0
#         1                      [always delicious Everything]  2.0
#
#                                                   attributes  \
# index
# 306994  0  [restaurant -> atmosphere, restaurant -> atmos...
#         1                                  [food -> variety]
# 306995  0          [food-quantity, restaurant -> atmosphere]
#         1                           [food -> variety, staff]
#         2                                  [food -> quality]
# ...                                                      ...
# 1038122 1                                  [food -> quality]
# 1038123 0                                            [staff]
#         1                           [food -> quality, staff]
# 1038125 0                                  [food -> quality]
#         1                                  [food -> quality]
#
#                                sentiments  \
# index
# 306994  0  [positive, positive, positive]
#         1                      [positive]
# 306995  0            [positive, positive]
#         1            [negative, positive]
#         2                       [neutral]
# ...                                   ...
# 1038122 1                       [neutral]
# 1038123 0                      [positive]
#         1            [positive, positive]
# 1038125 0                      [positive]
#         1                      [positive]
#
#                                               review_content
# index
# 306994  0  Hey Mrs. Robinson! \n\nThe Graduate was a fant...
#         1  Hey Mrs. Robinson! \n\nThe Graduate was a fant...
# 306995  0  The rooms are decent sized, and the view is aw...
#         1  The rooms are decent sized, and the view is aw...
#         2  The rooms are decent sized, and the view is aw...
# ...                                                      ...
# 1038122 1  Mehh... came in at 9pm, one hour before close....
# 1038123 0  I love coming to Panera! Ashley Love and Luke ...
#         1  I love coming to Panera! Ashley Love and Luke ...
# 1038125 0  Love Panera bread! So lucky to have them cater...
#         1  Love Panera bread! So lucky to have them cater...
#
# [74883 rows x 13 columns]

# %%
yelp_sent_df.to_pickle("../data/yelp/snippext_yelp_sent_df.pkl")

# %% [markdown]
# # Data Filter

# %%
yelp_sent_df = pd.read_pickle("../data/yelp/snippext_yelp_sent_df.pkl")

# %%
yelp_sent_df
# Out:
#                 domain                                    categories_list  \
# index
# 306994  0       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         1       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# 306995  0       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         1       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         2       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# ...                ...                                                ...
# 1038122 1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038123 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038125 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#
#                                                   categories            name  \
# index
# 306994  0  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         1  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# 306995  0  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         1  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         2  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# ...                                                      ...             ...
# 1038122 1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038123 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#         1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038125 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#         1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#
#                       business_id  \
# index
# 306994  0  iCCsd62g79PDjswXaqxltw
#         1  iCCsd62g79PDjswXaqxltw
# 306995  0  iCCsd62g79PDjswXaqxltw
#         1  iCCsd62g79PDjswXaqxltw
#         2  iCCsd62g79PDjswXaqxltw
# ...                           ...
# 1038122 1  6bgjcFOy4WHMyw62_1V9Pw
# 1038123 0  6bgjcFOy4WHMyw62_1V9Pw
#         1  6bgjcFOy4WHMyw62_1V9Pw
# 1038125 0  6bgjcFOy4WHMyw62_1V9Pw
#         1  6bgjcFOy4WHMyw62_1V9Pw
#
#                                                    sentences  \
# index
# 306994  0  Gorgeous 70 's vintage feel with that modern t...
#         1  I especially liked the convenience of the Norm...
# 306995  0  The rooms are decent sized , and the view is a...
#         1  Employees for the most part after nice althoug...
#         2  The ' theme ' of the hotel I found to be kind ...
# ...                                                      ...
# 1038122 1                             Tomato soup was ok .
# 1038123 0        The staff here is so amazing and friendly !
#         1                 Great food and wonderful service !
# 1038125 0                                Love Panera bread !
#         1                   Everything is always delicious .
#
#                                      opinions               aspects  \
# index
# 306994  0  [modern, boutique style, Gorgeous]  [twist, hotel, feel]
#         1                             [liked]         [convenience]
# 306995  0             [decent sized, awesome]         [rooms, view]
#         1                 [metrosexual, nice]      [men, Employees]
#         2                            [cheesy]               [hotel]
# ...                                       ...                   ...
# 1038122 1                                [ok]         [Tomato soup]
# 1038123 0              [amazing and friendly]               [staff]
#         1                  [Great, wonderful]       [food, service]
# 1038125 0                              [Love]              [Panera]
#         1                  [always delicious]          [Everything]
#
#                                         opinion_aspect_pairs  sid  \
# index
# 306994  0  [modern twist, boutique style hotel, Gorgeous ...  2.0
#         1                                [liked convenience]  3.0
# 306995  0                 [decent sized rooms, awesome view]  0.0
#         1                  [metrosexual men, nice Employees]  1.0
#         2                                     [cheesy hotel]  3.0
# ...                                                      ...  ...
# 1038122 1                                   [ok Tomato soup]  6.0
# 1038123 0                       [amazing and friendly staff]  2.0
#         1                    [Great food, wonderful service]  4.0
# 1038125 0                                      [Love Panera]  0.0
#         1                      [always delicious Everything]  2.0
#
#                                                   attributes  \
# index
# 306994  0  [restaurant -> atmosphere, restaurant -> atmos...
#         1                                  [food -> variety]
# 306995  0          [food-quantity, restaurant -> atmosphere]
#         1                           [food -> variety, staff]
#         2                                  [food -> quality]
# ...                                                      ...
# 1038122 1                                  [food -> quality]
# 1038123 0                                            [staff]
#         1                           [food -> quality, staff]
# 1038125 0                                  [food -> quality]
#         1                                  [food -> quality]
#
#                                sentiments  \
# index
# 306994  0  [positive, positive, positive]
#         1                      [positive]
# 306995  0            [positive, positive]
#         1            [negative, positive]
#         2                       [neutral]
# ...                                   ...
# 1038122 1                       [neutral]
# 1038123 0                      [positive]
#         1            [positive, positive]
# 1038125 0                      [positive]
#         1                      [positive]
#
#                                               review_content
# index
# 306994  0  Hey Mrs. Robinson! \n\nThe Graduate was a fant...
#         1  Hey Mrs. Robinson! \n\nThe Graduate was a fant...
# 306995  0  The rooms are decent sized, and the view is aw...
#         1  The rooms are decent sized, and the view is aw...
#         2  The rooms are decent sized, and the view is aw...
# ...                                                      ...
# 1038122 1  Mehh... came in at 9pm, one hour before close....
# 1038123 0  I love coming to Panera! Ashley Love and Luke ...
#         1  I love coming to Panera! Ashley Love and Luke ...
# 1038125 0  Love Panera bread! So lucky to have them cater...
#         1  Love Panera bread! So lucky to have them cater...
#
# [74883 rows x 13 columns]

# %% [markdown]
# ## Select single-aspect comments

# %%
yelp_sent_df = yelp_sent_df[yelp_sent_df['aspects'].str.len() == 1]

# %%
yelp_sent_df['sentiments'].value_counts()
# Out:
# [positive]    44612
# [negative]    12193
# [neutral]      4021
# Name: sentiments, dtype: int64

# %% [markdown]
# ## Filter neutral comments

# %%
yelp_sent_df = yelp_sent_df[yelp_sent_df['sentiments'].apply(lambda x: all([sentiment != 'neutral' for sentiment in x]))]

# %%
yelp_sent_df
# Out:
#                 domain                                    categories_list  \
# index
# 306994  1       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# 306995  3       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         4       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# 306997  0       Hotels  [Venues & Event Spaces, Event Planning & Servi...
#         3       Hotels  [Venues & Event Spaces, Event Planning & Servi...
# ...                ...                                                ...
# 1038121 4  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038122 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038123 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038125 0  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         1  Restaurants  [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#
#                                                   categories            name  \
# index
# 306994  1  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# 306995  3  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         4  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# 306997  0  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
#         3  Venues & Event Spaces, Event Planning & Servic...  Graduate Tempe
# ...                                                      ...             ...
# 1038121 4  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038122 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038123 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
# 1038125 0  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#         1  Breakfast & Brunch, Soup, Food, Bagels, Salad,...    Panera Bread
#
#                       business_id  \
# index
# 306994  1  iCCsd62g79PDjswXaqxltw
# 306995  3  iCCsd62g79PDjswXaqxltw
#         4  iCCsd62g79PDjswXaqxltw
# 306997  0  iCCsd62g79PDjswXaqxltw
#         3  iCCsd62g79PDjswXaqxltw
# ...                           ...
# 1038121 4  6bgjcFOy4WHMyw62_1V9Pw
# 1038122 0  6bgjcFOy4WHMyw62_1V9Pw
# 1038123 0  6bgjcFOy4WHMyw62_1V9Pw
# 1038125 0  6bgjcFOy4WHMyw62_1V9Pw
#         1  6bgjcFOy4WHMyw62_1V9Pw
#
#                                                    sentences  \
# index
# 306994  1  I especially liked the convenience of the Norm...
# 306995  3              Oh and hallway carpet is terrible .
#         4  Overall very pleasant stay and would like to r...
# 306997  0              Awesome place to stay when near ASU .
#         3  However , the carpet pattern on the floor leve...
# ...                                                      ...
# 1038121 4  Table was weird , dirty , and wobbly , like it...
# 1038122 0                           - Saddest grilled cheese
# 1038123 0        The staff here is so amazing and friendly !
# 1038125 0                                Love Panera bread !
#         1                   Everything is always delicious .
#
#                          opinions           aspects  \
# index
# 306994  1                 [liked]     [convenience]
# 306995  3              [terrible]  [hallway carpet]
#         4         [very pleasant]            [stay]
# 306997  0               [Awesome]           [place]
#         3               [hideous]    [floor levels]
# ...                           ...               ...
# 1038121 4                 [weird]           [Table]
# 1038122 0               [Saddest]  [grilled cheese]
# 1038123 0  [amazing and friendly]           [staff]
# 1038125 0                  [Love]          [Panera]
#         1      [always delicious]      [Everything]
#
#                     opinion_aspect_pairs  sid                  attributes  \
# index
# 306994  1            [liked convenience]  3.0           [food -> variety]
# 306995  3      [terrible hallway carpet]  4.0  [restaurant -> atmosphere]
#         4           [very pleasant stay]  5.0                 [wait-time]
# 306997  0                [Awesome place]  0.0            [recommendation]
#         3         [hideous floor levels]  3.0  [restaurant -> atmosphere]
# ...                                  ...  ...                         ...
# 1038121 4                  [weird Table]  6.0     [restaurant -> comfort]
# 1038122 0       [Saddest grilled cheese]  4.0           [food -> quality]
# 1038123 0   [amazing and friendly staff]  2.0                     [staff]
# 1038125 0                  [Love Panera]  0.0           [food -> quality]
#         1  [always delicious Everything]  2.0           [food -> quality]
#
#            sentiments                                     review_content
# index
# 306994  1  [positive]  Hey Mrs. Robinson! \n\nThe Graduate was a fant...
# 306995  3  [negative]  The rooms are decent sized, and the view is aw...
#         4  [positive]  The rooms are decent sized, and the view is aw...
# 306997  0  [positive]  Awesome place to stay when near ASU. Friendly ...
#         3  [negative]  Awesome place to stay when near ASU. Friendly ...
# ...               ...                                                ...
# 1038121 4  [negative]  We ordered two sandwiches, two sodas, and a bo...
# 1038122 0  [negative]  Mehh... came in at 9pm, one hour before close....
# 1038123 0  [positive]  I love coming to Panera! Ashley Love and Luke ...
# 1038125 0  [positive]  Love Panera bread! So lucky to have them cater...
#         1  [positive]  Love Panera bread! So lucky to have them cater...
#
# [56805 rows x 13 columns]

# %%
yelp_sent_df['sentiments'].value_counts()
# Out:
# [positive]    44612
# [negative]    12193
# Name: sentiments, dtype: int64

# %%
yelp_sent_df.shape
# Out:
# (56805, 13)

# %% [markdown]
# ## Select high-quality comments

# %% [markdown]
# **Select reviews having more than two sentences (comments)**

# %%
yelp_sent_df = yelp_sent_df.reset_index()

# %%
yelp_sent_df = yelp_sent_df.groupby(['index']).filter(lambda grp: len(grp) > 2)

# %%
yelp_sent_df = yelp_sent_df.set_index(['index', 'level_1']).sort_index()

# %%
yelp_sent_df
# Out:
#                       domain  \
# index   level_1
# 306997  0             Hotels
#         3             Hotels
#         4             Hotels
# 307005  0             Hotels
#         1             Hotels
# ...                      ...
# 1038117 3        Restaurants
#         4        Restaurants
# 1038121 2        Restaurants
#         3        Restaurants
#         4        Restaurants
#
#                                                    categories_list  \
# index   level_1
# 306997  0        [Venues & Event Spaces, Event Planning & Servi...
#         3        [Venues & Event Spaces, Event Planning & Servi...
#         4        [Venues & Event Spaces, Event Planning & Servi...
# 307005  0        [Venues & Event Spaces, Event Planning & Servi...
#         1        [Venues & Event Spaces, Event Planning & Servi...
# ...                                                            ...
# 1038117 3        [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         4        [Breakfast & Brunch, Soup, Food, Bagels, Salad...
# 1038121 2        [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         3        [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#         4        [Breakfast & Brunch, Soup, Food, Bagels, Salad...
#
#                                                         categories  \
# index   level_1
# 306997  0        Venues & Event Spaces, Event Planning & Servic...
#         3        Venues & Event Spaces, Event Planning & Servic...
#         4        Venues & Event Spaces, Event Planning & Servic...
# 307005  0        Venues & Event Spaces, Event Planning & Servic...
#         1        Venues & Event Spaces, Event Planning & Servic...
# ...                                                            ...
# 1038117 3        Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#         4        Breakfast & Brunch, Soup, Food, Bagels, Salad,...
# 1038121 2        Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#         3        Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#         4        Breakfast & Brunch, Soup, Food, Bagels, Salad,...
#
#                            name             business_id  \
# index   level_1
# 306997  0        Graduate Tempe  iCCsd62g79PDjswXaqxltw
#         3        Graduate Tempe  iCCsd62g79PDjswXaqxltw
#         4        Graduate Tempe  iCCsd62g79PDjswXaqxltw
# 307005  0        Graduate Tempe  iCCsd62g79PDjswXaqxltw
#         1        Graduate Tempe  iCCsd62g79PDjswXaqxltw
# ...                         ...                     ...
# 1038117 3          Panera Bread  6bgjcFOy4WHMyw62_1V9Pw
#         4          Panera Bread  6bgjcFOy4WHMyw62_1V9Pw
# 1038121 2          Panera Bread  6bgjcFOy4WHMyw62_1V9Pw
#         3          Panera Bread  6bgjcFOy4WHMyw62_1V9Pw
#         4          Panera Bread  6bgjcFOy4WHMyw62_1V9Pw
#
#                                                          sentences  \
# index   level_1
# 306997  0                    Awesome place to stay when near ASU .
#         3        However , the carpet pattern on the floor leve...
#         4               The bar at the bottom has decent servers .
# 307005  0                                     Reasonable price .
#         1              The decor is unjust and college themed .
# ...                                                            ...
# 1038117 3                        Tomato soup is always perfect .
#         4        My favorite location is the Boca Park just bec...
# 1038121 2                      Place felt dirty and disorganized .
#         3        Place was deserted on Saturday afternoon , now...
#         4        Table was weird , dirty , and wobbly , like it...
#
#                          opinions         aspects  \
# index   level_1
# 306997  0               [Awesome]         [place]
#         3               [hideous]  [floor levels]
#         4                [decent]       [servers]
# 307005  0            [Reasonable]         [price]
#         1                [unjust]         [decor]
# ...                           ...             ...
# 1038117 3        [always perfect]   [Tomato soup]
#         4              [favorite]      [location]
# 1038121 2                 [dirty]         [Place]
#         3              [deserted]         [Place]
#         4                 [weird]         [Table]
#
#                          opinion_aspect_pairs  sid  \
# index   level_1
# 306997  0                     [Awesome place]  0.0
#         3              [hideous floor levels]  3.0
#         4                    [decent servers]  4.0
# 307005  0                  [Reasonable price]  1.0
#         1                      [unjust decor]  2.0
# ...                                       ...  ...
# 1038117 3        [always perfect Tomato soup]  4.0
#         4                 [favorite location]  5.0
# 1038121 2                       [dirty Place]  4.0
#         3                    [deserted Place]  5.0
#         4                       [weird Table]  6.0
#
#                                  attributes  sentiments  \
# index   level_1
# 306997  0                  [recommendation]  [positive]
#         3        [restaurant -> atmosphere]  [negative]
#         4                           [staff]  [positive]
# 307005  0                 [value-for-money]  [positive]
#         1        [restaurant -> atmosphere]  [negative]
# ...                                     ...         ...
# 1038117 3                 [food -> quality]  [positive]
#         4                  [recommendation]  [positive]
# 1038121 2        [restaurant -> atmosphere]  [negative]
#         3        [restaurant -> atmosphere]  [negative]
#         4           [restaurant -> comfort]  [negative]
#
#                                                     review_content
# index   level_1
# 306997  0        Awesome place to stay when near ASU. Friendly ...
#         3        Awesome place to stay when near ASU. Friendly ...
#         4        Awesome place to stay when near ASU. Friendly ...
# 307005  0        Didn't know what to expect,  but we were pleas...
#         1        Didn't know what to expect,  but we were pleas...
# ...                                                            ...
# 1038117 3        This location is closest to my place in Spring...
#         4        This location is closest to my place in Spring...
# 1038121 2        We ordered two sandwiches, two sodas, and a bo...
#         3        We ordered two sandwiches, two sodas, and a bo...
#         4        We ordered two sandwiches, two sodas, and a bo...
#
# [28074 rows x 13 columns]

# %%
yelp_sent_df.to_pickle("../data/yelp/snippext_yelp_sent_df_single_aspect_5_domains_top_50.pkl")
